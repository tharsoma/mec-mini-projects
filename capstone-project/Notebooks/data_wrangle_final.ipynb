# %%
#imports
import os, json
import pandas as pd
from datetime import timedelta
import yfinance as yf

# %%
#options
pd.set_option('display.max_colwidth',100)
pd.set_option('display.max_rows',1000)

# %%
#utillities
def append_all_json_data(folderPath: str, list_of_jsons) -> pd.DataFrame:
    df = pd.DataFrame()
    for element in list_of_jsons:
        full_path = folderPath+"/"+element
        #print (full_path)
        df = df.append(pd.read_json(full_path))
    return df

def get_raw_sentiment(sentimentPath):
    if sentimentPath == None:
        return None
    else:
        return sentimentPath["basic"]

def subtract_days_from_date(date, days):
    """Subtract days from a date and return the date.
    
    Args: 
        date (string): Date string in YYYY-MM-DD format. 
        days (int): Number of days to subtract from date
    
    Returns: 
        date (date): Date in YYYY-MM-DD with X days subtracted. 
    """
    
    subtracted_date = pd.to_datetime(date) - timedelta(days=days)
    subtracted_date = subtracted_date.strftime("%Y-%m-%d")

    return subtracted_date

def get_stockprice_at_time(day):
    #print(day)
    try:
        val = hist.loc[day].Close
    except KeyError:
        d = subtract_days_from_date(day, 1)
        val = get_stockprice_at_time(d)
        
    return round(val,3)

# %%
#Bag of words for sentiment prediction
#https://www.kaggle.com/datasets/sbhatti/financial-sentiment-analysis
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import re
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer

dataset = pd.read_csv('bagofwords_data.csv')
dataset= dataset[dataset["Sentiment"].str.contains("neutral")==False]
dataset=dataset.reset_index(drop=True)
sentiment = {'positive': 1,'negative': 0}
dataset.Sentiment = [sentiment[item] for item in dataset.Sentiment]
corpus = []


    
for i in range(0,2712):
    review = re.sub('[^a-zA-Z]',' ',dataset['Sentence'][i])
    review = review.lower()
    review = review.split()
    ps = PorterStemmer()
    all_stopwords = stopwords.words('english')
    all_stopwords.remove('not')
    review = [ps.stem(word) for word in review if not word in set(all_stopwords)]
    review = ' '.join(review)
    corpus.append(review)

from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features=1500)
x = cv.fit_transform(corpus).toarray()
y = dataset.iloc[:,-1].values

from sklearn.model_selection import train_test_split
#train, test = train_test_split(dataset, test_size = 0.33, random_state=42)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.79, random_state=42)

from sklearn.naive_bayes import GaussianNB
classifier = GaussianNB()
classifier.fit(x_train,y_train)
y_pred = classifier.predict(x_test)

def get_bow_sentiment(msg):
    msg_review = msg
    msg_review = re.sub('[^a-zA-Z]',' ',msg_review)
    msg_review = msg_review.lower()
    msg_review = msg_review.split()
    ps = PorterStemmer()
    all_stopwords = stopwords.words('english')
    all_stopwords.remove('not')
    msg_review = [ps.stem(word) for word in msg_review if not word in set(all_stopwords)]
    msg_review = ' '.join(msg_review)
    user_corpus = [msg_review]
    new_x_test = cv.transform(user_corpus).toarray()
    new_y_pred = classifier.predict(new_x_test)
    if new_y_pred[0] == 0:
        return 'Bearish'
    else:
        return 'Bullish'

from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test,y_pred)
print(cm)
accuracy_score(y_test,y_pred)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Developer\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [[ 363  325]
#  [ 306 1149]]
# 0.705552963135791

# %%
path_to_json = 'Data/AAPL'
json_files = [pos_json for pos_json in os.listdir(path_to_json) if pos_json.endswith('.json')]

# %%
len(json_files)
# Out:
# 1374

# %%
raw_json_data = append_all_json_data(path_to_json,json_files)
raw_json_data=df.reset_index(drop=True)
raw_json_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41220 entries, 0 to 41219
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               41220 non-null  int64
#  1   body             41220 non-null  object
#  2   created_at       41220 non-null  datetime64[ns, UTC]
#  3   user             41220 non-null  object
#  4   source           41220 non-null  object
#  5   symbols          41220 non-null  object
#  6   conversation     14000 non-null  object
#  7   likes            24928 non-null  object
#  8   mentioned_users  41220 non-null  object
#  9   entities         41220 non-null  object
#  10  links            5446 non-null   object
#  11  reshare_message  1348 non-null   object
#  12  reshares         1131 non-null   object
#  13  owned_symbols    328 non-null    object
# dtypes: datetime64[ns, UTC](1), int64(1), object(12)
# memory usage: 4.4+ MB

# %%
appl = yf.Ticker("AAPL")
hist = appl.history(period="max")

# %%
new_dataframe = pd.DataFrame(columns=["time_created","username","message","sentiment","derived_sentiment","stock_price"])
for i in range(df.shape[0]):
    ts = raw_json_data["created_at"][i]
    day = str(ts.year)+"-"+str(ts.month)+"-"+str(ts.day)
    new_dataframe.loc[i]= [raw_json_data["created_at"][i],raw_json_data["user"][i]["username"],raw_json_data["body"][i],get_raw_sentiment(raw_json_data["entities"][i]["sentiment"]),get_bow_sentiment(raw_json_data["body"][i]),get_stockprice_at_time(day)]

# %%
new_dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 41220 entries, 0 to 41219
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   time_created       41220 non-null  datetime64[ns, UTC]
#  1   username           41220 non-null  object
#  2   message            41220 non-null  object
#  3   sentiment          20101 non-null  object
#  4   derived_sentiment  41220 non-null  object
#  5   stock_price        41220 non-null  float64
# dtypes: datetime64[ns, UTC](1), float64(1), object(4)
# memory usage: 2.2+ MB

# %%
new_dataframe.sample(n=100)
# Out:
#                    time_created              username  \
# 6684  2021-12-17 14:28:48+00:00           CptKangaroo
# 3668  2021-12-16 00:52:01+00:00               JDSoCal
# 22803 2022-01-05 19:30:06+00:00          hoyasaxa1978
# 28425 2022-01-12 18:35:38+00:00            DrD_Trades
# 7187  2021-12-17 16:40:58+00:00       Barren_Wufffett
# 39686 2022-01-25 20:51:04+00:00        investclem1682
# 1304  2021-11-09 16:37:29+00:00          BoilingPoint
# 7950  2021-12-18 16:28:35+00:00               Rome777
# 14137 2021-12-27 18:12:25+00:00               sionele
# 40344 2022-01-26 09:38:12+00:00              moongoal
# 10003 2021-12-21 15:01:15+00:00               Eyeeye1
# 30285 2022-01-14 16:38:47+00:00   from_rags_to_riches
# 20262 2022-01-03 20:36:01+00:00          PumpTheJuice
# 2679  2021-12-15 19:29:37+00:00        moneyallday313
# 24536 2022-01-07 07:17:18+00:00                Saxxon
# 35216 2022-01-21 14:35:39+00:00           NewYorkerHK
# 34515 2022-01-20 21:34:31+00:00        OneWolfCapital
# 1041  2021-11-09 11:22:09+00:00     eatfloatsbuyboats
# 7533  2021-12-17 19:43:07+00:00            KansasCash
# 7765  2021-12-17 21:19:40+00:00         BFofBearsWife
# 24720 2022-01-07 15:26:29+00:00           DAYSCALPER1
# 24465 2022-01-07 03:09:01+00:00       GetTheseTendies
# 21636 2022-01-04 17:09:59+00:00           Flashindesi
# 24159 2022-01-06 20:42:01+00:00              cleanair
# 26116 2022-01-10 16:12:09+00:00                SPQR23
# 13553 2021-12-26 20:45:21+00:00        Aigner_Andreas
# 5113  2021-12-16 18:09:56+00:00     retailinvestorlol
# 19532 2022-01-03 17:45:45+00:00             KINGDOGGO
# 23978 2022-01-06 18:52:48+00:00                 vonGr
# 28283 2022-01-12 16:01:57+00:00           bigblue1972
# 21905 2022-01-04 19:46:25+00:00              beingDiv
# 19377 2022-01-03 16:03:47+00:00           ScottiePipn
# 27412 2022-01-11 17:17:18+00:00            danman1732
# 14070 2021-12-27 17:27:27+00:00          HODLHOLD4EVa
# 30751 2022-01-15 13:39:57+00:00            PippoBaudo
# 5863  2021-12-16 21:13:32+00:00              djonez90
# 32221 2022-01-19 00:13:06+00:00  NicksOptionsStratagy
# 19269 2022-01-03 15:27:44+00:00                BigBod
# 20297 2022-01-03 20:43:11+00:00         Sharkyshark26
# 22070 2022-01-04 21:21:35+00:00     eatfloatsbuyboats
# 8938  2021-12-20 15:30:21+00:00        jillsantiago10
# 14929 2021-12-28 04:32:12+00:00  OpportunisticGrizzly
# 16396 2021-12-29 15:24:35+00:00                 KatNY
# 17788 2021-12-30 20:40:45+00:00             vinituict
# 8341  2021-12-20 01:10:25+00:00         Lettingitride
#
#                                                                                                    message  \
# 6684      $AAPL Had a great run. Time to back and fill. Perfectly healthy. Will be back to new highs soon.
# 3668                                 @HollywoodWolf777 Apple has 271 stores in the USA dumb bunny. \n$AAPL
# 22803              $AAPL    🍏 Just, Breathe.  Keep your eyes on the Indices.  Here is where they are, now:
# 28425                                                                                     $AAPL 177 $ soon
# 7187                                 $AAPL \n\nSomeone help these damn Bulls. They are sinking. Hahahahaha
# 39686        $AAPL \n\nYikes short never stop attacking .. they are stubborn as fuck to make red to go on.
# 1304   $COIN $AAPL Then Apple loses!  Don’t worry Tim will have a change of heart when his users start ...
# 7950   $AAPL $AMZN $GOOG $GOOGL $FB https://newsfilter.io/articles/kickstarter-discord-and-others-are-r...
# 14137                                                                         $AAPL huge 14k wall at 179.5
# 40344                                           $AAPL glad I didn&#39;t panic sell. Holding for retirement
# 10003                                          $AAPL I think we are building a floor at $170.00 right now!
# 30285                                                                                   $AAPL come on!!!!!
# 20262  Combine Walmart, Disney, Netflix, Nike, Exxon Mobil, Coca-Cola, Comcast, Morgan Stanley, McDonal...
# 2679                                               $AAPL one day we all should be bears and one day bulls👻
# 24536  $SPY Weak $AAPL and $TSLA today was the indicator this is a failed bounce.  Sit tight for the NA...
# 35216                                                                        $AAPL apple buying Peloton???
# 34515                                     $SPY $PTON $NFLX $LCID $AAPL - -  &quot;how low can it go?&quot;
# 1041                                                            $AAPL $FATBB get in while you can $FATBB 🚀
# 7533                                                        $SPY $AAPL $TSLA Charlie doesn&#39;t follow me
# 7765                                                                              $aapl The bulls are here
# 24720  $AAPL I don’t like what I see but, if trend is your friend you find a way to trade it. It’s not ...
# 24465  $AAPL GLTA don&#39;t bet the house, yada yada. Your money, your decisions, don&#39;t blame other...
# 21636                                                                              $AAPL Feb calls anyone?
# 24159                                            $AAPL terrible week so far. 3 great weeks, 1 bad. Bummer.
# 26116                        $QCOM Need to see $AAPL and $AMZN turn then you will a ST bottom here on QCOM
# 13553  #Levermann #Global #MegaCap #Sell WK51 $AAPL (1), $AMZN (-2), $FB (0), $V (-1), $UNH (2), JPM (1...
# 5113   $AAPL what % of Apple users once held a #DefundThePolice sign? I&#39;m thinking between 80 and 90%?
# 19532                    $AAPL the fact that it can’t even go 10 cents down without a rebound back up is 😫
# 23978                                                                $AAPL about to pop. Sellers drying up
# 40996  $CCL   \nThis is trending into the $40.00 arena by mid summer…… \n \nFriends at: \n$AAPL  $NVDA ...
# 19579                                               $AAPL bulls out bears go hibernate 🤪🍏🍏🍏🍏🍏🤲🏻🤲🏻🎉🎉❤️❤️🍏🍏🍏
# 9293   $AAPL I can’t find one person that is worried about Omicron. WS stop spinning news to support yo...
# 24531                                                                           $AAPL 4T mkt cap next week
# 30467                                $AAPL Do not sleep on big tech like $MSFT and $AAPL etc. Buy quality.
# 23827                         $AAPL market green and they’re holding it down. F the shorts and hf’s crooks
# 10266                                                                        $AAPL \n\n200 … Santa 🎅 rally
# 12187                                  $NAKD $TSLA $OCGN $AAPL https://www.youtube.com/watch?v=b3q2YPOD7CA
# 9244                                                                    $AAPL I thought it’s closing green
# 28168                                                                                 $AAPL Lift off 1hour
# 3805                                               $AAPL apple is about to spuge on you bears and shorts 😂
# 6717                                                                  $AAPL wanna get trapped again bulls?
# 13438  $AAPL \n\n🍏🎄\nWill the Third Time Be a Charm for Apple?\n\nRecent upgrades make a strong case fo...
# 36139                                                                              $AAPL Just keep adding!
# 8570   $AAPL and $MCK are showing a bull flag pattern today. https://www.chartmill.com/stock/stock-scre...
# 26042  $AAPL your absolutely retarded to think this stock is going to crash…. There is absolutely stupi...
# 5462                                  $AAPL will stay dead cat tomorrow, as they have to kill the options.
# 10754                                                                            $AAPL headed back to $185
# 10703                                $TSLA $AAPL HODLers block all noice and stick to your convictions 💎💎💎
# 33047  $COIN $SQ $PYPL $GOOGL $AAPL According to the report, Google has formed partnerships with crypto...
# 1684   $spy $qqq $AAPL \n\nRetail sales 0.3%, Exp. 0.9%\nRetail sales ex auto and gas 0.2%, Exp. 0.8%\n...
# 2267                                                                                         $AAPL retards
# 37005                                                         $SPY $PTON $TSLA $AAPL $ARKK POOTZ GANG FTW.
# 2087   $AAPL if chip makers come down then the market is fucking rekt. Other than that. Some strength o...
# 40363                                                                            $AAPL what time fed talks
# 7628                                                                               $QQQ $SPY $AAPL $TSLA #
# 5038                                              $AAPL bought my first iPhone this week, you can blame me
# 1089   $VIAC so here’s the reason for suppressed price ? This is bogus . $AAPL can buy them out and if ...
# 9000                                      $AAPL obvious shorters patterns here\nGonna get interesting soon
# 5897   $AAPL   🍏 Volume soared into the Close, trading 148.9 Million on the Day.  In the “final second”...
# 3861   $SPY what is that one thing that would crash market to REALITY? It does not have to be a March 2...
# 18155                                                                   $AAPL really fighting to hold $178
# 10296                                         $AAPL \n\nIt appears that it is heading to 172 \n\nLet’s go!
# 9689                                                         $AAPL green to red tomorrow and red wed again
# 872          $AMZN $AAPL   🧞‍♂️. Exclusively  $SPY   🧞‍♂️.  \n\nhttps://apple.news/A9X7pBSdHQPO8cVcfuKWgBQ
# 35643  @NFL Conference Semi Winners @hfrfromthefloor says $PENN last chance for big revenues March Madn...
# 22172                                               $TSLA $AAPL What gets to $4 trillion market cap first?
# 36743  $RBLX $aapl $snap $TWTR  \nFutes green so far but it can flip tomorrow morning... \n \nhopefully...
# 31919  $AAPL This shit is down nearly 10%. How much discount are people looking for. Come on get real. ...
# 11347                                                           $AAPL 175+ today Apple you can do it baby.
# 514                            $AAPL they’re bull flagging. It’s ugly but don’t bet against the King Maker
# 11009                                                        $AAPL short term bearish long term always up.
# 23473                  $BAC treasury going rip banks 🏦 up $SPY  $TSLA $AAPL and shit on tech so $BAC it is
# 4953   $AAPL \n\nNo bad news and no problem with AAPL with lots of positive side.\n\nWhat can I say? Th...
# 23020  $SPY $QQQ $AMD $AAPL $AMC well fuck. Gonna need those christmas presents back for my broker. Reb...
# 5485                                                                      $AAPL love all the volatility…..
# 11348                                                                            $AAPL all that for $1??!!
# 40110            $AAPL January they said they only sold about 40million what revenue is gonna be down bad.
# 2491   Is this good for your portfolio? $AAPL in +5.9% Uptrend, rising for three consecutive days on De...
# 13708  Weekly Stock Market Review: https://www.reddit.com/user/Fatherthinger/comments/rpkr0n/weekly_sto...
# 576    $AAPL This stock usually consolidates for weeks on end then moves higher about $10 or so….. and ...
# 1595   $AAPL because this is currently following at only half the percentage drop rate of the Nasdaq, t...
# 20037                                                                              $AAPL like I said hold.
# 2350                                                              $AAPL AWESOME Iphone hotspot connections
# 11152                                                                   $AAPL 🔜1️⃣5️⃣5️⃣ #WhosKnow??? $SPY
# 28283                                                                  $AAPL 170 puts Jan 21 back in play.
# 21905  Every damn #powerofthepeople event/call-buying spree...\nThese stocks $AAPL $TSLA retreat and $H...
# 19377                                                                       $AAPL genius level buying here
# 27412                                   $AAPL tim cook made $268,500 every day in 2021...thats ridiculous.
# 14070  $AAPL Only 1 thing is certain at this point. Apple will reach 3T. Why are some against this? I s...
# 30751                                                                $BMRN $AAPL $GOOG $TSLA look at us...
# 5863   $AAPL dumb &quot;buy the dip&quot; pampers coming out the woods.even a misleading reddit blog at...
# 32221  $AAPL happily setting orders to add shares to my long position in the low 160’s. Fingers crossed...
# 19269            $AAPL sold weekly $185 calls for a nice 0.81 premium. Easy $240. Think they’ll be safe. 😎
# 20297                                           $AAPL 180 puts hardly budging in value with this down tick
# 22070  $AAPL better days are coming follow me to $FATBB buy at 13 bounc is coming soon up 627% in reven...
# 8938   $AAPL - &#39;iPhone 14 will get 48MP camera sensor, folding lens arriving with iPhone 15&#39; -A...
# 14929                          $AAPL Loaded on $170 puts. What goes up must come down. Gravity always wins
# 16396                                  $AAPL Bought a few shares. Will continue to accumulate on any dips.
# 17788  Apple Unexpectedly Reveals Dazzling Future For Apple Watch $AAPL Thermometer &amp; Watch https:/...
# 8341                                                     $SPY triple negative futes by morning $AAPL $NVDA
#
#       sentiment derived_sentiment  stock_price
# 6684       None           Bearish      170.922
# 3668    Bullish           Bearish      172.041
# 22803      None           Bullish      174.697
# 28425   Bullish           Bearish      175.307
# 7187    Bearish           Bullish      170.922
# 39686      None           Bearish      159.577
# 1304       None           Bearish      150.618
# 7950       None           Bullish      170.922
# 14137   Bullish           Bullish      180.101
# 40344   Bullish           Bearish      159.487
# 10003   Bullish           Bearish      172.770
